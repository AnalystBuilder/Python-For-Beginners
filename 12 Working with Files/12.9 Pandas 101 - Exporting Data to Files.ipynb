# %% [markdown]
# # Pandas 101 - Exporting Data to Files

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population.csv')

df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.groupby('Continent')['2022 Population', '2020 Population'].count()
# Out:
# C:\Users\alexf\AppData\Local\Temp\ipykernel_1462408\3068146767.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Continent')['2022 Population', '2020 Population'].count()
#                2022 Population  2020 Population
# Continent
# Africa                      56               57
# Asia                        49               49
# Europe                      49               50
# North America               40               40
# Oceania                     22               23
# South America               14               14

# %%
df2 = df.groupby('Continent')['2022 Population', '2020 Population'].count()
# Out:
# C:\Users\alexf\AppData\Local\Temp\ipykernel_1462408\2787865554.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df.groupby('Continent')['2022 Population', '2020 Population'].count()

# %%
df2.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population_grouped.csv')

# %%
df2.to_excel(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population_grouped_excel.xlsx')
