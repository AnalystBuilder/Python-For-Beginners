# %% [markdown]
# # Pandas 101 - Opening Files with Pandas

# %%
read_file = open(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\countries of the world.csv','r')

print(read_file.read())

read_file.close()
# Out:
# Country,Region
# Afghanistan ,ASIA (EX. NEAR EAST)
# Albania ,EASTERN EUROPE
# Algeria ,NORTHERN AFRICA
# American Samoa ,OCEANIA
# Andorra ,WESTERN EUROPE
# Angola ,SUB-SAHARAN AFRICA
# Anguilla ,LATIN AMER. & CARIB
# Antigua & Barbuda ,LATIN AMER. & CARIB
# Argentina ,LATIN AMER. & CARIB
# Armenia ,C.W. OF IND. STATES
# Aruba ,LATIN AMER. & CARIB
# Australia ,OCEANIA
# Austria ,WESTERN EUROPE
# Azerbaijan ,C.W. OF IND. STATES
# "Bahamas, The ",LATIN AMER. & CARIB
# Bahrain ,NEAR EAST
# Bangladesh ,ASIA (EX. NEAR EAST)
# Barbados ,LATIN AMER. & CARIB
# Belarus ,C.W. OF IND. STATES
# Belgium ,WESTERN EUROPE
# Belize ,LATIN AMER. & CARIB
# Benin ,SUB-SAHARAN AFRICA
# Bermuda ,NORTHERN AMERICA
# Bhutan ,ASIA (EX. NEAR EAST)
# Bolivia ,LATIN AMER. & CARIB
# Bosnia & Herzegovina ,EASTERN EUROPE
# Botswana ,SUB-SAHARAN AFRICA
# Brazil ,LATIN AMER. & CARIB
# British Virgin Is. ,LATIN AMER. & CARIB
# Brunei ,ASIA (EX. NEAR EAST)
# Bulgaria ,EASTERN EUROPE
# Burkina Faso ,SUB-SAHARAN AFRICA
# ...

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\countries of the world.csv')
df
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
pd.set_option('display.max.rows',230)

# %%
df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\countries of the world.csv', header = None)
df
# Out:
#                                      0                                    1
# 0                              Country                               Region
# 1                         Afghanistan         ASIA (EX. NEAR EAST)
# 2                             Albania   EASTERN EUROPE
# 3                             Algeria   NORTHERN AFRICA
# 4                      American Samoa   OCEANIA
# 5                             Andorra   WESTERN EUROPE
# 6                              Angola   SUB-SAHARAN AFRICA
# 7                            Anguilla               LATIN AMER. & CARIB
# 8                   Antigua & Barbuda               LATIN AMER. & CARIB
# 9                           Argentina               LATIN AMER. & CARIB
# 10                            Armenia                  C.W. OF IND. STATES
# 11                              Aruba               LATIN AMER. & CARIB
# 12                          Australia   OCEANIA
# 13                            Austria   WESTERN EUROPE
# ...

# %%
df2 = pd.read_json(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\json_sample.json')
df2
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
pd.set_option('display.max.columns',40)

# %%
df3 = pd.read_excel(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population_excel_workbook.xlsx', sheet_name = 'Sheet1')
df3
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]
