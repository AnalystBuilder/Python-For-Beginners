# %% [markdown]
# # Pandas 101 - Manipulating and Exploring Data in DataFrame

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population_excel_workbook.xlsx', sheet_name = 'Sheet1')

df
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
pd.set_option('display.max.rows', 235)
pd.set_option('display.max.columns', 50)

# %%
df
# Out:
#      Rank CCA3                           Country              Capital
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     234 non-null    int64
#  1   CCA3     234 non-null    object
#  2   Country  234 non-null    object
#  3   Capital  234 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.4+ KB

# %%
df.shape
# Out:
# (234, 4)

# %%
df.head(10)
# Out:
#    Rank CCA3              Country           Capital
# 0    36  AFG          Afghanistan             Kabul
# 1   138  ALB              Albania            Tirana
# 2    34  DZA              Algeria           Algiers
# 3   213  ASM       American Samoa         Pago Pago
# 4   203  AND              Andorra  Andorra la Vella
# 5    42  AGO               Angola            Luanda
# 6   224  AIA             Anguilla        The Valley
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8    33  ARG            Argentina      Buenos Aires
# 9   140  ARM              Armenia           Yerevan

# %%
df.tail(10)
# Out:
#      Rank CCA3            Country       Capital
# 224    43  UZB         Uzbekistan      Tashkent
# 225   181  VUT            Vanuatu     Port-Vila
# 226   234  VAT       Vatican City  Vatican City
# 227    51  VEN          Venezuela       Caracas
# 228    16  VNM            Vietnam         Hanoi
# 229   226  WLF  Wallis and Futuna      Mata-Utu
# 230   172  ESH     Western Sahara     El AaiÃºn
# 231    46  YEM              Yemen         Sanaa
# 232    63  ZMB             Zambia        Lusaka
# 233    74  ZWE           Zimbabwe        Harare

# %%
df['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
# 5       42
# 6      224
# 7      201
# 8       33
# 9      140
# 10     198
# 11      55
# 12      99
# 13      91
# 14     176
# 15     154
# 16       8
# 17     186
# 18      96
# 19      81
# 20     177
# 21      77
# 22     206
# 23     165
# 24      80
# 25     137
# 26     144
# 27       7
# 28     221
# 29     175
# 30     108
# 31      58
# 32      78
# 33      73
# 34      53
# 35      39
# 36     171
# 37     205
# 38     117
# 39      69
# 40      65
# 41       1
# 42      28
# 43     163
# 44     223
# 45     124
# 46     130
# 47      85
# 48     189
# 49     158
# 50      88
# 51     115
# 52     160
# 53     204
# 54      84
# 55      15
# 56      67
# 57      14
# 58     112
# 59     152
# 60     132
# 61     156
# 62     159
# 63      12
# 64     231
# 65     209
# 66     162
# 67     118
# 68      23
# 69     184
# 70     183
# 71     146
# 72     142
# 73     131
# 74      19
# 75      47
# ...

# %%
df.loc[1]
# Out:
# Rank           138
# CCA3           ALB
# Country    Albania
# Capital     Tirana
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Rank           138
# CCA3           ALB
# Country    Albania
# Capital     Tirana
# Name: 1, dtype: object

# %%
df2 = pd.read_excel(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population_excel_workbook.xlsx', sheet_name = 'Sheet1', index_col = 'Country')

df2
# Out:
#                                   Rank CCA3              Capital
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG       Saint Johnâ€™s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
df2.loc['Afghanistan']
# Out:
# Rank          36
# CCA3         AFG
# Capital    Kabul
# Name: Afghanistan, dtype: object

# %%
df2.iloc[0]
# Out:
# Rank          36
# CCA3         AFG
# Capital    Kabul
# Name: Afghanistan, dtype: object

# %%
df
# Out:
#      Rank CCA3                           Country              Capital
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df[df['Rank'] <= 10]
# Out:
#      Rank CCA3        Country           Capital
# 16      8  BGD     Bangladesh             Dhaka
# 27      7  BRA         Brazil          Brasilia
# 41      1  CHN          China           Beijing
# 92      2  IND          India         New Delhi
# 93      4  IDN      Indonesia           Jakarta
# 131    10  MEX         Mexico       Mexico City
# 149     6  NGA        Nigeria             Abuja
# 156     5  PAK       Pakistan         Islamabad
# 171     9  RUS         Russia            Moscow
# 221     3  USA  United States  Washington, D.C.

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital
# 219    97  ARE          United Arab Emirates         Abu Dhabi
# 220    21  GBR                United Kingdom            London
# 221     3  USA                 United States  Washington, D.C.
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie

# %%
df[df['Rank'] <= 10].sort_values(by = ['Country','Rank'], ascending = [True,False])
# Out:
#      Rank CCA3        Country           Capital
# 16      8  BGD     Bangladesh             Dhaka
# 27      7  BRA         Brazil          Brasilia
# 41      1  CHN          China           Beijing
# 92      2  IND          India         New Delhi
# 93      4  IDN      Indonesia           Jakarta
# 131    10  MEX         Mexico       Mexico City
# 149     6  NGA        Nigeria             Abuja
# 156     5  PAK       Pakistan         Islamabad
# 171     9  RUS         Russia            Moscow
# 221     3  USA  United States  Washington, D.C.

# %%
df3 = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Tutorials\Pandas_Folder\world_population.csv')

df3
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df3.groupby('Continent')

# %%
group_by_frame = df3.groupby('Continent')

# %%
group_by_frame.mean()
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# ...

# %%
df3.groupby('Continent').mean()
# Out:
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa          92.157895     2.545588e+07     2.387144e+07     2.141970e+07
# Asia            77.560000     9.632739e+07     9.495513e+07     8.916500e+07
# Europe         124.500000     1.505537e+07     1.491584e+07     1.502745e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     2.046386e+06     1.910149e+06     1.756664e+06
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.889820e+07     1.459837e+07     1.137696e+07
# Asia              8.908777e+07     8.058084e+07     4.864000e+07
# Europe            1.471228e+07     1.481769e+07     1.478520e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
# ...

# %%
df3.groupby('Continent').count()
# Out:
#                Rank  CCA3  Country  Capital  2022 Population  2020 Population  \
# Continent
# Africa           57    57       57       57               56               57
# Asia             50    50       50       50               49               49
# Europe           50    50       50       50               49               50
# North America    40    40       40       40               40               40
# Oceania          23    23       23       23               22               23
# South America    14    14       14       14               14               14
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa                      54               54               56
# Asia                        50               47               46
# Europe                      49               50               49
# North America               40               40               40
# Oceania                     23               23               23
# ...

# %%
df3.groupby('Continent')['2022 Population', '2020 Population'].count()
# Out:
# C:\Users\alexf\AppData\Local\Temp\ipykernel_1408220\4141281419.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3.groupby('Continent')['2022 Population', '2020 Population'].count()
#                2022 Population  2020 Population
# Continent
# Africa                      56               57
# Asia                        49               49
# Europe                      49               50
# North America               40               40
# Oceania                     22               23
# South America               14               14
